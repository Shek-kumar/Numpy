# %% [markdown]
# * **Histograms are used to plot frequency of a variable.**
# * **In histograms, x axis contains a variable and y axis will be a frequency of that variable**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# * **We have a sample data of blood sugar level of different patients, we will try to plot number of patients by blood range and try to figure out how many patients are normal, pre-diabetic and diabetic**
# * **rwidth means relative parameterof the graph**

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")
plt.hist(blood_sugar, rwidth=0.8)     # by default number of bins is set to 10
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #**using bin parameter**

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")
plt.hist(blood_sugar,rwidth=0.4,bins=5)
# Out:
# (array([6., 1., 2., 2., 2.]),
#  array([ 77. ,  91.6, 106.2, 120.8, 135.4, 150. ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# #**Histogram showing normal, pre-diabetic and diabetic patients distribution**
#
# * **80-100: Normal**
# * **100-125: Pre-diabetic**
# * **125-150: Diabetic**

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

plt.hist(blood_sugar,rwidth=0.4,bins=[80,100,125,150],color='g')
# Out:
# (array([6., 2., 4.]),
#  array([ 80., 100., 125., 150.]),
#  <BarContainer object of 3 artists>)

# %% [markdown]
# #**Using histtype=step**

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

plt.hist(blood_sugar,bins=[80,100,125,150],rwidth=0.95,histtype='step')
# Out:
# (array([6., 2., 4.]),
#  array([ 80., 100., 125., 150.]),
#  [<matplotlib.patches.Polygon at 0x7fbe8fbf0340>])

# %% [markdown]
# #**Mutiple data samples in a histogram**

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

plt.hist([blood_sugar_men,blood_sugar_women],bins=[80,100,125,150],color=['r','y'],label=['male','female'])
plt.legend()

# %% [markdown]
# #**horizontal orientation**

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

plt.hist([blood_sugar_men,blood_sugar_women],bins=[80,100,125,150],color=['r','y'],label=['male','female'],orientation='horizontal')
plt.legend()

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]
blood_sugar_transgender=[70,80,90,100,85,81,92,99,98,95,85,125,130]

plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

plt.hist([blood_sugar_men,blood_sugar_women,blood_sugar_transgender],bins=[80,100,125,150],label=['male','female','Transgender'])    # we can use here color=['g','r','y'] as well
plt.legend()

# %%
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]
blood_sugar_transgender=[70,80,90,100,85,81,92,99,98,95,85,125,130]

plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")

plt.hist([blood_sugar_men,blood_sugar_women,blood_sugar_transgender],bins=[80,100,125,150],label=['male','female','Transgender'],color=['g','r','y'],orientation='horizontal')    # we can use here color=['g','r','y'] as well
plt.legend()
